# %% [markdown]
# ###### create a confusion matrix and evaluate specificity , sensitivity and accurycy of the data given below.

# %%
import pandas as pd

# %%
actual = [1,0,1,1,0]
predicted = [1,0,0,1,1]

# %%
df = pd.DataFrame({'Actual':actual,
                   'Predicted':predicted})

# %%
print(df)
# Out:
#    Actual  Predicted
# 0       1          1
# 1       0          0
# 2       1          0
# 3       1          1
# 4       0          1

# %%
TP = sum((df['Actual']==1)&(df['Predicted']==1))
TN = sum((df['Actual']==0)&(df['Predicted']==0))
FP = sum((df['Actual']==0)&(df['Predicted']==1))
FN = sum((df['Actual']==1)&(df['Predicted']==0))

# %%
print(f"TP:{TP},TN:{TN},FP:{FP},FN:{FN}")
# Out:
# TP:2,TN:1,FP:1,FN:1

# %%
Sensitivity = TP/(TP+FN)
Sensitivity
# Out:
# 0.6666666666666666

# %%
Specificity = TN/(TN+FP)
Specificity
# Out:
# 0.5

# %%
Accuracy = (TP+TN)/(TP+FP+FN+TN)
Accuracy
# Out:
# 0.6

# %%
Precision = TP/(TP+FP)
Precision
# Out:
# 0.6666666666666666

# %% [markdown]
# ###### Q-253

# %% [markdown]
# ###### 1. import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,accuracy_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ###### 2. Preprocessing

# %%
df['mathpass'] = np.where(df['math score'] >= 50,1,0)
df['readpass'] = np.where(df['reading score'] >= 50,1,0)
df['writepass'] = np.where(df['writing score'] >= 50,1,0)
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# ###### 3. Drop Colummns

# %%
df.drop(['math score' , 'reading score' , 'writing score'] , axis = 1 , inplace = True)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  mathpass  readpass  writepass
# 0                      none         1         1          1
# ...

# %% [markdown]
# ###### 4. Create Overall Pass Column

# %%
df['overallpass'] = np.where(
(df['mathpass'] == 1) &
(df['readpass'] == 1) &
(df['writepass'] == 1),1,0
)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  mathpass  readpass  writepass  overallpass
# ...

# %% [markdown]
# ###### 5. One Hot Encoding (get dummies)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   mathpass                     1000 non-null   int32
#  6   readpass                     1000 non-null   int32
#  7   writepass                    1000 non-null   int32
#  8   overallpass                  1000 non-null   int32
# dtypes: int32(4), object(5)
# memory usage: 54.8+ KB

# %%
category = ['gender','race/ethnicity','parental level of education','lunch','test preparation course']
df_encode = pd.get_dummies(df.drop(columns = 'mathpass'),columns = category , drop_first = True)

# %%
df_encode
# Out:
#      readpass  writepass  overallpass  gender_male  race/ethnicity_group B  \
# 0           1          1            1            0                       1
# 1           1          1            1            0                       0
# 2           1          1            1            0                       1
# 3           1          0            0            1                       0
# 4           1          1            1            1                       0
# ..        ...        ...          ...          ...                     ...
# 995         1          1            1            0                       0
# 996         1          1            1            1                       0
# 997         1          1            1            0                       0
# 998         1          1            1            0                       0
# 999         1          1            1            0                       0
#
# ...

# %% [markdown]
# ###### 6. Handel Missing Value

# %%
df_encode.isna().sum()
# Out:
# readpass                                         0
# writepass                                        0
# overallpass                                      0
# gender_male                                      0
# race/ethnicity_group B                           0
# race/ethnicity_group C                           0
# race/ethnicity_group D                           0
# race/ethnicity_group E                           0
# parental level of education_bachelor's degree    0
# parental level of education_high school          0
# parental level of education_master's degree      0
# parental level of education_some college         0
# parental level of education_some high school     0
# lunch_standard                                   0
# test preparation course_none                     0
# dtype: int64

# %% [markdown]
# ###### 7. Extract Fetures and Label

# %%
x = df_encode
y = df['mathpass']

# %% [markdown]
# ###### 8. Split the Data

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 , random_state = 10)

# %%
print(x.shape)
print(x_train.shape)
print(x_test.shape)
print(y.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1000, 15)
# (800, 15)
# (200, 15)
# (1000,)
# (800,)
# (200,)

# %% [markdown]
# ###### 9. KNN CLASSIFICATION

# %%
bestaccuracy = 0
bestk = 1
for k in range(1,20):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train,y_train)
    y_pred = knn.predict(x_test)
    accuracy = accuracy_score(y_test,y_pred)
    if accuracy > bestaccuracy:
        bestk = k
        bestaccuracy = accuracy
print("Best accuracy is " , bestaccuracy)
print("Best k is " , bestk)
# Out:
# Best accuracy is  0.945
# Best k is  9

# %% [markdown]
# ###### 10. Train with best knn

# %%
knn = KNeighborsClassifier(n_neighbors=bestk)
knn.fit(x_train,y_train)
y_pred_knn = knn.predict(x_test)

# %% [markdown]
# ###### 11. Confusion Matrix of knn

# %%
cm_knn = confusion_matrix(y_test , y_pred_knn)
print(cm_knn)
# Out:
# [[ 16   6]
#  [  5 173]]

# %%
tn , fp , fn , tp = cm_knn.ravel()

# %%
Sensitivity = tp/(tp+fn)
Specificity = tn/(tn+fp)
accuracy_knn = accuracy_score(y_test,y_pred_knn)
print(Sensitivity)
print(Specificity)
print(accuracy_knn)
# Out:
# 0.9719101123595506
# 0.7272727272727273
# 0.945

# %% [markdown]
# ###### 12. Decision Tree

# %%
bestdepth = 1
bestacctree = 0
for depth in range(1,11):
    tree = DecisionTreeClassifier(max_depth=depth,random_state=10)
    tree.fit(x_train,y_train)
    y_pred = tree.predict(x_test)
    accuracy = accuracy_score(y_test,y_pred)
    if accuracy > bestacctree:
        bestdepth = depth
        bestacctree = accuracy
print(bestdepth,bestacctree)
# Out:
# 8 0.97

# %% [markdown]
# ###### 13. fit decision tree with best depth

# %%
tree = DecisionTreeClassifier(max_depth=bestdepth,random_state=10)
tree.fit(x_train,y_train)
