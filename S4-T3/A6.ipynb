# %% [markdown]
# ###### Get Coordinates (Geocoding API)
# (https://openweathermap.org/api/geocoding-api)

# %%
import requests , json

# %%
def getcoordinates():
    apikey = "8edd6bea302a33d53a6e920a247e2c72"
    city = "Ahmedabad"
    url = f"http://api.openweathermap.org/geo/1.0/direct?q={city}&appid={apikey}"
    response = requests.get(url)
    print(response)
    coordinates = response.json()
    print(coordinates)
    latitude = coordinates[0]['lat']
    longitude = coordinates[0]['lon']
    return (latitude,longitude)
lat,lon = getcoordinates() 
print(lat)
print(lon)
# Out:
# <Response [200]>
# [{'name': 'Ahmedabad', 'local_names': {'he': 'אחמדאבאד', 'ascii': 'Ahmedabad', 'or': 'ଅହମଦାବାଦ', 'uk': 'Ахмедабад', 'mr': 'अहमदाबाद', 'gu': 'અમદાવાદ', 'ta': 'அகமதாபாத்', 'de': 'Ahmedabad', 'te': 'అహ్మదాబాద్', 'ru': 'Ахмадабад', 'hi': 'अहमदाबाद', 'cs': 'Ahmadábád', 'feature_name': 'Ahmedabad', 'oc': 'Ahmadabad', 'ja': 'アフマダーバード', 'ur': 'احمد آباد', 'zh': '艾哈迈达巴德', 'kn': 'ಅಹ್ಮದಾಬಾದ್', 'en': 'Ahmedabad', 'pa': 'ਅਹਿਮਦਾਬਾਦ', 'eo': 'Ahmadabado', 'pl': 'Ahmadabad', 'ar': 'أحمد آباد', 'ml': 'അഹമ്മദാബാദ്'}, 'lat': 23.0216238, 'lon': 72.5797068, 'country': 'IN', 'state': 'Gujarat'}]
# 23.0216238
# 72.5797068

# %% [markdown]
# ###### Five Day Forecast

# %% [markdown]
# ###### BEFORE EDIT

# %%
def fiveday():
    apikey = "8edd6bea302a33d53a6e920a247e2c72"
    url = f"http://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={apikey}"
    response = requests.get(url)
    print(response)
    five_days = response.json()
    return pprint.pprint(five_days)
fiveday()
# Out:
# <Response [200]>
# {'city': {'coord': {'lat': 23.0216, 'lon': 72.5797},
#           'country': 'IN',
#           'id': 1279233,
#           'name': 'Ahmedabad',
#           'population': 3719710,
#           'sunrise': 1748996626,
#           'sunset': 1749045151,
#           'timezone': 19800},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 92},
#            'dt': 1749016800,
#            'dt_txt': '2025-06-04 06:00:00',
#            'main': {'feels_like': 308.66,
#                     'grnd_level': 1000,
#                     'humidity': 41,
#                     'pressure': 1006,
#                     'sea_level': 1006,
#                     'temp': 307.05,
#                     'temp_kf': 0,
#                     'temp_max': 307.05,
#                     'temp_min': 307.05},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 204, 'gust': 4.64, 'speed': 4.15}},
#           {'clouds': {'all': 71},
#            'dt': 1749027600,
#            'dt_txt': '2025-06-04 09:00:00',
#            'main': {'feels_like': 309.49,
#                     'grnd_level': 998,
#                     'humidity': 36,
#                     'pressure': 1005,
#                     'sea_level': 1005,
#                     'temp': 308.3,
#                     'temp_kf': -2.5,
#                     'temp_max': 310.8,
#                     'temp_min': 308.3},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 207, 'gust': 3.01, 'speed': 3.26}},
#           {'clouds': {'all': 42},
#            'dt': 1749038400,
#            'dt_txt': '2025-06-04 12:00:00',
#            'main': {'feels_like': 310.09,
#                     'grnd_level': 996,
#                     'humidity': 27,
#                     'pressure': 1003,
#                     'sea_level': 1003,
#                     'temp': 310.16,
#                     'temp_kf': -1.56,
#                     'temp_max': 311.72,
#                     'temp_min': 310.16},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 236, 'gust': 2.95, 'speed': 3.2}},
#           {'clouds': {'all': 33},
#            'dt': 1749049200,
#            'dt_txt': '2025-06-04 15:00:00',
#            'main': {'feels_like': 307.46,
#                     'grnd_level': 999,
#                     'humidity': 49,
#                     'pressure': 1004,
#                     'sea_level': 1004,
#                     'temp': 305.25,
#                     'temp_kf': 0,
#                     'temp_max': 305.25,
#                     'temp_min': 305.25},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03n',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 200, 'gust': 9.72, 'speed': 7.18}},
#           {'clouds': {'all': 21},
#            'dt': 1749060000,
#            'dt_txt': '2025-06-04 18:00:00',
#            'main': {'feels_like': 306.81,
#                     'grnd_level': 1000,
#                     'humidity': 56,
#                     'pressure': 1006,
#                     'sea_level': 1006,
#                     'temp': 304.03,
#                     'temp_kf': 0,
#                     'temp_max': 304.03,
#                     'temp_min': 304.03},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02n',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 189, 'gust': 7.51, 'speed': 4.92}},
#           {'clouds': {'all': 0},
#            'dt': 1749070800,
#            'dt_txt': '2025-06-04 21:00:00',
#            'main': {'feels_like': 305.4,
#                     'grnd_level': 1000,
#                     'humidity': 57,
#                     'pressure': 1005,
#                     'sea_level': 1005,
#                     'temp': 303.15,
#                     'temp_kf': 0,
#                     'temp_max': 303.15,
#                     'temp_min': 303.15},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01n',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 278, 'gust': 7.35, 'speed': 5.16}},
#           {'clouds': {'all': 0},
#            'dt': 1749081600,
#            'dt_txt': '2025-06-05 00:00:00',
#            'main': {'feels_like': 304.48,
#                     'grnd_level': 1001,
#                     'humidity': 63,
#                     'pressure': 1006,
#                     'sea_level': 1006,
#                     'temp': 302.05,
#                     'temp_kf': 0,
#                     'temp_max': 302.05,
#                     'temp_min': 302.05},
#            'pop': 0.22,
#            'rain': {'3h': 0.13},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 276, 'gust': 5.85, 'speed': 4.21}},
#           {'clouds': {'all': 1},
#            'dt': 1749092400,
#            'dt_txt': '2025-06-05 03:00:00',
#            'main': {'feels_like': 305.97,
#                     'grnd_level': 1004,
#                     'humidity': 54,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 303.8,
#                     'temp_kf': 0,
#                     'temp_max': 303.8,
#                     'temp_min': 303.8},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 272, 'gust': 3.21, 'speed': 3.14}},
#           {'clouds': {'all': 2},
#            'dt': 1749103200,
#            'dt_txt': '2025-06-05 06:00:00',
#            'main': {'feels_like': 309.57,
#                     'grnd_level': 1003,
#                     'humidity': 39,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 307.87,
#                     'temp_kf': 0,
#                     'temp_max': 307.87,
#                     'temp_min': 307.87},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 234, 'gust': 3.61, 'speed': 3.73}},
#           {'clouds': {'all': 1},
#            'dt': 1749114000,
#            'dt_txt': '2025-06-05 09:00:00',
#            'main': {'feels_like': 312.27,
#                     'grnd_level': 1001,
#                     'humidity': 31,
#                     'pressure': 1006,
#                     'sea_level': 1006,
#                     'temp': 310.77,
#                     'temp_kf': 0,
#                     'temp_max': 310.77,
#                     'temp_min': 310.77},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 235, 'gust': 2.33, 'speed': 3.09}},
#           {'clouds': {'all': 12},
#            'dt': 1749124800,
#            'dt_txt': '2025-06-05 12:00:00',
#            'main': {'feels_like': 311.76,
#                     'grnd_level': 999,
#                     'humidity': 27,
#                     'pressure': 1004,
#                     'sea_level': 1004,
#                     'temp': 311.23,
#                     'temp_kf': 0,
#                     'temp_max': 311.23,
#                     'temp_min': 311.23},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02d',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 232, 'gust': 3.25, 'speed': 2.51}},
#           {'clouds': {'all': 88},
#            'dt': 1749135600,
#            'dt_txt': '2025-06-05 15:00:00',
#            'main': {'feels_like': 309.08,
#                     'grnd_level': 1001,
#                     'humidity': 40,
#                     'pressure': 1007,
#                     'sea_level': 1007,
#                     'temp': 307.44,
#                     'temp_kf': 0,
#                     'temp_max': 307.44,
#                     'temp_min': 307.44},
#            'pop': 0.2,
#            'rain': {'3h': 0.12},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 194, 'gust': 7.21, 'speed': 6.57}},
#           {'clouds': {'all': 62},
#            'dt': 1749146400,
#            'dt_txt': '2025-06-05 18:00:00',
#            'main': {'feels_like': 307.08,
#                     'grnd_level': 1003,
#                     'humidity': 47,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 305.3,
#                     'temp_kf': 0,
#                     'temp_max': 305.3,
#                     'temp_min': 305.3},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04n',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 196, 'gust': 7.36, 'speed': 4.84}},
#           {'clouds': {'all': 4},
#            'dt': 1749157200,
#            'dt_txt': '2025-06-05 21:00:00',
#            'main': {'feels_like': 305.98,
#                     'grnd_level': 1002,
#                     'humidity': 52,
#                     'pressure': 1007,
#                     'sea_level': 1007,
#                     'temp': 304.04,
#                     'temp_kf': 0,
#                     'temp_max': 304.04,
#                     'temp_min': 304.04},
#            'pop': 0.2,
#            'rain': {'3h': 0.19},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 172, 'gust': 2.66, 'speed': 1.69}},
#           {'clouds': {'all': 2},
#            'dt': 1749168000,
#            'dt_txt': '2025-06-06 00:00:00',
#            'main': {'feels_like': 307.02,
#                     'grnd_level': 1003,
#                     'humidity': 61,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 303.57,
#                     'temp_kf': 0,
#                     'temp_max': 303.57,
#                     'temp_min': 303.57},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01n',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 310, 'gust': 5.09, 'speed': 3.43}},
#           {'clouds': {'all': 0},
#            'dt': 1749178800,
#            'dt_txt': '2025-06-06 03:00:00',
#            'main': {'feels_like': 308.06,
#                     'grnd_level': 1004,
#                     'humidity': 55,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 304.79,
#                     'temp_kf': 0,
#                     'temp_max': 304.79,
#                     'temp_min': 304.79},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 289, 'gust': 4.32, 'speed': 4.16}},
#           {'clouds': {'all': 0},
#            'dt': 1749189600,
#            'dt_txt': '2025-06-06 06:00:00',
#            'main': {'feels_like': 312.1,
#                     'grnd_level': 1004,
#                     'humidity': 42,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 308.71,
#                     'temp_kf': 0,
#                     'temp_max': 308.71,
#                     'temp_min': 308.71},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 283, 'gust': 2.62, 'speed': 3.59}},
#           {'clouds': {'all': 11},
#            'dt': 1749200400,
#            'dt_txt': '2025-06-06 09:00:00',
#            'main': {'feels_like': 314.6,
#                     'grnd_level': 1001,
#                     'humidity': 31,
#                     'pressure': 1006,
#                     'sea_level': 1006,
#                     'temp': 312.05,
#                     'temp_kf': 0,
#                     'temp_max': 312.05,
#                     'temp_min': 312.05},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02d',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 296, 'gust': 3.84, 'speed': 3.55}},
#           {'clouds': {'all': 29},
#            'dt': 1749211200,
#            'dt_txt': '2025-06-06 12:00:00',
#            'main': {'feels_like': 313.3,
#                     'grnd_level': 999,
#                     'humidity': 27,
#                     'pressure': 1005,
#                     'sea_level': 1005,
#                     'temp': 312.16,
#                     'temp_kf': 0,
#                     'temp_max': 312.16,
#                     'temp_min': 312.16},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 238, 'gust': 3.46, 'speed': 3.6}},
#           {'clouds': {'all': 44},
#            'dt': 1749222000,
#            'dt_txt': '2025-06-06 15:00:00',
#            'main': {'feels_like': 311.12,
#                     'grnd_level': 1002,
#                     'humidity': 42,
#                     'pressure': 1007,
#                     'sea_level': 1007,
#                     'temp': 308.22,
#                     'temp_kf': 0,
#                     'temp_max': 308.22,
#                     'temp_min': 308.22},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03n',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 219, 'gust': 8.64, 'speed': 6.52}},
#           {'clouds': {'all': 27},
#            'dt': 1749232800,
#            'dt_txt': '2025-06-06 18:00:00',
#            'main': {'feels_like': 308.92,
#                     'grnd_level': 1003,
#                     'humidity': 48,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 306.17,
#                     'temp_kf': 0,
#                     'temp_max': 306.17,
#                     'temp_min': 306.17},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03n',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 283, 'gust': 8.11, 'speed': 5.53}},
#           {'clouds': {'all': 73},
#            'dt': 1749243600,
#            'dt_txt': '2025-06-06 21:00:00',
#            'main': {'feels_like': 307.51,
#                     'grnd_level': 1003,
#                     'humidity': 57,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 304.27,
#                     'temp_kf': 0,
#                     'temp_max': 304.27,
#                     'temp_min': 304.27},
#            'pop': 0.56,
#            'rain': {'3h': 0.39},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 272, 'gust': 4.16, 'speed': 2.53}},
#           {'clouds': {'all': 86},
#            'dt': 1749254400,
#            'dt_txt': '2025-06-07 00:00:00',
#            'main': {'feels_like': 306.16,
#                     'grnd_level': 1003,
#                     'humidity': 59,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 303.35,
#                     'temp_kf': 0,
#                     'temp_max': 303.35,
#                     'temp_min': 303.35},
#            'pop': 0.4,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 268, 'gust': 5.94, 'speed': 4.06}},
#           {'clouds': {'all': 26},
#            'dt': 1749265200,
#            'dt_txt': '2025-06-07 03:00:00',
#            'main': {'feels_like': 307.05,
#                     'grnd_level': 1004,
#                     'humidity': 52,
#                     'pressure': 1010,
#                     'sea_level': 1010,
#                     'temp': 304.64,
#                     'temp_kf': 0,
#                     'temp_max': 304.64,
#                     'temp_min': 304.64},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 281, 'gust': 5.33, 'speed': 4.56}},
#           {'clouds': {'all': 16},
#            'dt': 1749276000,
#            'dt_txt': '2025-06-07 06:00:00',
#            'main': {'feels_like': 312.06,
#                     'grnd_level': 1004,
#                     'humidity': 40,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 309.03,
#                     'temp_kf': 0,
#                     'temp_max': 309.03,
#                     'temp_min': 309.03},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02d',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 279, 'gust': 4.42, 'speed': 4.42}},
#           {'clouds': {'all': 4},
#            'dt': 1749286800,
#            'dt_txt': '2025-06-07 09:00:00',
#            'main': {'feels_like': 314.22,
#                     'grnd_level': 1001,
#                     'humidity': 31,
#                     'pressure': 1006,
#                     'sea_level': 1006,
#                     'temp': 311.85,
#                     'temp_kf': 0,
#                     'temp_max': 311.85,
#                     'temp_min': 311.85},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 288, 'gust': 3.42, 'speed': 4.08}},
#           {'clouds': {'all': 10},
#            'dt': 1749297600,
#            'dt_txt': '2025-06-07 12:00:00',
#            'main': {'feels_like': 314.18,
#                     'grnd_level': 999,
#                     'humidity': 28,
#                     'pressure': 1004,
#                     'sea_level': 1004,
#                     'temp': 312.46,
#                     'temp_kf': 0,
#                     'temp_max': 312.46,
#                     'temp_min': 312.46},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 313, 'gust': 5.32, 'speed': 4.67}},
#           {'clouds': {'all': 42},
#            'dt': 1749308400,
#            'dt_txt': '2025-06-07 15:00:00',
#            'main': {'feels_like': 311.55,
#                     'grnd_level': 1001,
#                     'humidity': 40,
#                     'pressure': 1006,
#                     'sea_level': 1006,
#                     'temp': 308.77,
#                     'temp_kf': 0,
#                     'temp_max': 308.77,
#                     'temp_min': 308.77},
#            'pop': 0.44,
#            'rain': {'3h': 0.16},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 214, 'gust': 4.93, 'speed': 4.2}},
#           {'clouds': {'all': 48},
#            'dt': 1749319200,
#            'dt_txt': '2025-06-07 18:00:00',
#            'main': {'feels_like': 307.94,
#                     'grnd_level': 1003,
#                     'humidity': 48,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 305.65,
#                     'temp_kf': 0,
#                     'temp_max': 305.65,
#                     'temp_min': 305.65},
#            'pop': 0.59,
#            'rain': {'3h': 0.43},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 283, 'gust': 6.48, 'speed': 4.28}},
#           {'clouds': {'all': 56},
#            'dt': 1749330000,
#            'dt_txt': '2025-06-07 21:00:00',
#            'main': {'feels_like': 306.2,
#                     'grnd_level': 1003,
#                     'humidity': 53,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 304.05,
#                     'temp_kf': 0,
#                     'temp_max': 304.05,
#                     'temp_min': 304.05},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04n',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 257, 'gust': 6.17, 'speed': 4.99}},
#           {'clouds': {'all': 78},
#            'dt': 1749340800,
#            'dt_txt': '2025-06-08 00:00:00',
#            'main': {'feels_like': 306.04,
#                     'grnd_level': 1004,
#                     'humidity': 60,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 303.18,
#                     'temp_kf': 0,
#                     'temp_max': 303.18,
#                     'temp_min': 303.18},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04n',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 260, 'gust': 3.76, 'speed': 3.45}},
#           {'clouds': {'all': 85},
#            'dt': 1749351600,
#            'dt_txt': '2025-06-08 03:00:00',
#            'main': {'feels_like': 307.51,
#                     'grnd_level': 1004,
#                     'humidity': 56,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 304.39,
#                     'temp_kf': 0,
#                     'temp_max': 304.39,
#                     'temp_min': 304.39},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 270, 'gust': 6.79, 'speed': 5.83}},
#           {'clouds': {'all': 60},
#            'dt': 1749362400,
#            'dt_txt': '2025-06-08 06:00:00',
#            'main': {'feels_like': 311.1,
#                     'grnd_level': 1004,
#                     'humidity': 40,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 308.54,
#                     'temp_kf': 0,
#                     'temp_max': 308.54,
#                     'temp_min': 308.54},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 259, 'gust': 4.72, 'speed': 4.61}},
#           {'clouds': {'all': 12},
#            'dt': 1749373200,
#            'dt_txt': '2025-06-08 09:00:00',
#            'main': {'feels_like': 313.63,
#                     'grnd_level': 1001,
#                     'humidity': 33,
#                     'pressure': 1006,
#                     'sea_level': 1006,
#                     'temp': 311.13,
#                     'temp_kf': 0,
#                     'temp_max': 311.13,
#                     'temp_min': 311.13},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02d',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 244, 'gust': 4.6, 'speed': 5.01}},
#           {'clouds': {'all': 10},
#            'dt': 1749384000,
#            'dt_txt': '2025-06-08 12:00:00',
#            'main': {'feels_like': 313.32,
#                     'grnd_level': 1000,
#                     'humidity': 31,
#                     'pressure': 1005,
#                     'sea_level': 1005,
#                     'temp': 311.36,
#                     'temp_kf': 0,
#                     'temp_max': 311.36,
#                     'temp_min': 311.36},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 225, 'gust': 4.11, 'speed': 4.04}},
#           {'clouds': {'all': 24},
#            'dt': 1749394800,
#            'dt_txt': '2025-06-08 15:00:00',
#            'main': {'feels_like': 309.8,
#                     'grnd_level': 1002,
#                     'humidity': 50,
#                     'pressure': 1007,
#                     'sea_level': 1007,
#                     'temp': 306.33,
#                     'temp_kf': 0,
#                     'temp_max': 306.33,
#                     'temp_min': 306.33},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02n',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 199, 'gust': 7.96, 'speed': 5.97}},
#           {'clouds': {'all': 62},
#            'dt': 1749405600,
#            'dt_txt': '2025-06-08 18:00:00',
#            'main': {'feels_like': 308.82,
#                     'grnd_level': 1002,
#                     'humidity': 49,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 305.98,
#                     'temp_kf': 0,
#                     'temp_max': 305.98,
#                     'temp_min': 305.98},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04n',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 277, 'gust': 5.97, 'speed': 4.26}},
#           {'clouds': {'all': 55},
#            'dt': 1749416400,
#            'dt_txt': '2025-06-08 21:00:00',
#            'main': {'feels_like': 305.77,
#                     'grnd_level': 1001,
#                     'humidity': 60,
#                     'pressure': 1007,
#                     'sea_level': 1007,
#                     'temp': 303.04,
#                     'temp_kf': 0,
#                     'temp_max': 303.04,
#                     'temp_min': 303.04},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04n',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 271, 'gust': 8.52, 'speed': 5.83}},
#           {'clouds': {'all': 28},
#            'dt': 1749427200,
#            'dt_txt': '2025-06-09 00:00:00',
#            'main': {'feels_like': 304.95,
#                     'grnd_level': 1002,
#                     'humidity': 65,
#                     'pressure': 1007,
#                     'sea_level': 1007,
#                     'temp': 302.13,
#                     'temp_kf': 0,
#                     'temp_max': 302.13,
#                     'temp_min': 302.13},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03n',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 272, 'gust': 7.6, 'speed': 5.44}},
#           {'clouds': {'all': 1},
#            'dt': 1749438000,
#            'dt_txt': '2025-06-09 03:00:00',
#            'main': {'feels_like': 306.39,
#                     'grnd_level': 1004,
#                     'humidity': 57,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 303.69,
#                     'temp_kf': 0,
#                     'temp_max': 303.69,
#                     'temp_min': 303.69},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 265, 'gust': 6.31, 'speed': 5.33}}],
#  'message': 0}

# %% [markdown]
# ###### AFTER EDIT

# %%
def fiveday():
    apikey = "8edd6bea302a33d53a6e920a247e2c72"
    url = f"http://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={apikey}"
    response = requests.get(url)
    print(response)
    five_days = response.json()
    return pprint.pprint(five_days)
fiveday()
